# %% [markdown]
# # Notebook to donwload the materials from PCD
#
# Download this notebook and copy it to your google drive so you can modify it.
#
# This notebook will allow you to donwload the materials that you need to complete to pass the subject.
#
# ## First, mount your google drive so that you can modify the activities that you download
#
# This notebook will download the materials from an online repository. It will save them into your google drive so that you can save the changes that you make. To do this, we mount your google drive with the following command. Be sure to agree to mount the drive into your UOC gmail account.

# %%
# First, mount your google drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # First, mount your google drive
# ----> 2 from google.colab import drive
#       3 drive.mount("/content/drive")
#
# ModuleNotFoundError: No module named 'google'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# *Once* the drive is accessible for google colab, we move inside of your google drive.

# %%
# Move to the directtory that contains our google drive, into a folder called Colab_Notebooks!
# !ls
# Out:
# drive  sample_data

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# Check that we are in the correct folder
# If this is not correct you may need to create the folder mentioned above
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %% [markdown]
# # Download the subject materials
#
# Here you can download the Notebooks with all the material of each unit of the subject. Remember that these notebooks contain much of the theory necessary to complete the practices and obtain the knowledge and skills required for the course.
#
# *Remember to create a folder to separate the materials from the activities and their solutions.*

# %%
# enter activity number
unit_number = 9

# %%
# Download


# !git clone  https://gitlab.com/UOC/eimt/prog_datasci_2/resources/progds-1/cat/unit_{unit_number}.git
# Out:
# Cloning into 'unit_9'...
# Username for 'https://gitlab.com':
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Documents/Formación/Máster Data Science/Programación para la ciencia de datos/uoc-python-for-data-science/.venv/lib/python3.11/site-packages/IPython/utils/_process_posix.py:130, in ProcessHandler.system(self, cmd)
#     127 while True:
#     128     # res is the index of the pattern that caused the match, so we
#     129     # know whether we've finished (if we matched EOF) or not
# --> 130     res_idx = child.expect_list(patterns, self.read_timeout)
#     131     print(child.before[out_size:].decode(enc, 'replace'), end='')
#
# File ~/Documents/Formación/Máster Data Science/Programación para la ciencia de datos/uoc-python-for-data-science/.venv/lib/python3.11/site-packages/pexpect/spawnbase.py:383, in SpawnBase.expect_list(self, pattern_list, timeout, searchwindowsize, async_, **kw)
#     382 else:
# --> 383     return exp.expect_loop(timeout)
#
# File ~/Documents/Formación/Máster Data Science/Programación para la ciencia de datos/uoc-python-for-data-science/.venv/lib/python3.11/site-packages/pexpect/expect.py:169, in Expecter.expect_loop(self, timeout)
#     168 # Still have time left, so read more data
# --> 169 incoming = spawn.read_nonblocking(spawn.maxread, timeout)
#     170 if self.spawn.delayafterread is not None:
#
# File ~/Documents/Formación/Máster Data Science/Programación para la ciencia de datos/uoc-python-for-data-science/.venv/lib/python3.11/site-packages/pexpect/pty_spawn.py:500, in spawn.read_nonblocking(self, size, timeout)
#     497 # Because of the select(0) check above, we know that no data
#     498 # is available right now. But if a non-zero timeout is given
#     499 # (possibly timeout=None), we call select() with a timeout.
# --> 500 if (timeout != 0) and select(timeout):
#     501     return super(spawn, self).read_nonblocking(size)
#
# File ~/Documents/Formación/Máster Data Science/Programación para la ciencia de datos/uoc-python-for-data-science/.venv/lib/python3.11/site-packages/pexpect/pty_spawn.py:450, in spawn.read_nonblocking.<locals>.select(timeout)
#     449 def select(timeout):
# --> 450     return select_ignore_interrupts([self.child_fd], [], [], timeout)[0]
#
# File ~/Documents/Formación/Máster Data Science/Programación para la ciencia de datos/uoc-python-for-data-science/.venv/lib/python3.11/site-packages/pexpect/utils.py:143, in select_ignore_interrupts(iwtd, owtd, ewtd, timeout)
#     142 try:
# --> 143     return select.select(iwtd, owtd, ewtd, timeout)
#     144 except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[21], line 4
#       1 # Download
# ----> 4 get_ipython().system('git clone  https://gitlab.com/UOC/eimt/prog_datasci_2/resources/progds-1/cat/unit_{unit_number}.git')
#
# File ~/Documents/Formación/Máster Data Science/Programación para la ciencia de datos/uoc-python-for-data-science/.venv/lib/python3.11/site-packages/ipykernel/zmqshell.py:788, in ZMQInteractiveShell.system_piped(self, cmd)
#     786         self.user_ns["_exit_code"] = system(cmd)
#     787 else:
# --> 788     self.user_ns["_exit_code"] = system(self.var_expand(cmd, depth=1))
#
# File ~/Documents/Formación/Máster Data Science/Programación para la ciencia de datos/uoc-python-for-data-science/.venv/lib/python3.11/site-packages/IPython/utils/_process_posix.py:141, in ProcessHandler.system(self, cmd)
#     136         out_size = len(child.before)
#     137 except KeyboardInterrupt:
#     138     # We need to send ^C to the process.  The ascii code for '^C' is 3
#     139     # (the character is known as ETX for 'End of Text', see
#     140     # curses.ascii.ETX).
# --> 141     child.sendline(chr(3))
#     142     # Read and print any more output the program might produce on its
#     143     # way out.
#     144     try:
#
# File ~/Documents/Formación/Máster Data Science/Programación para la ciencia de datos/uoc-python-for-data-science/.venv/lib/python3.11/site-packages/pexpect/pty_spawn.py:578, in spawn.sendline(self, s)
#     572 '''Wraps send(), sending string ``s`` to child process, with
#     573 ``os.linesep`` automatically appended. Returns number of bytes
#     574 written.  Only a limited number of bytes may be sent for each
#     575 line in the default terminal mode, see docstring of :meth:`send`.
#     576 '''
#     577 s = self._coerce_send_string(s)
# --> 578 return self.send(s + self.linesep)
#
# File ~/Documents/Formación/Máster Data Science/Programación para la ciencia de datos/uoc-python-for-data-science/.venv/lib/python3.11/site-packages/pexpect/pty_spawn.py:569, in spawn.send(self, s)
#     566 self._log(s, 'send')
#     568 b = self._encoder.encode(s, final=False)
# --> 569 return os.write(self.child_fd, b)
#
# OSError: [Errno 5] Input/output error

# %% [markdown]
# # Donwload the activity from the online repository
#
# All that is left is downloading the activity. Choose the activity number (1,2,3 or 4) in the next cell and download it in the next one.
#
# *Remember to create a folder to separate the materials from the activities and their solutions.*

# %%
# enter activity number
activity_number = 1

# %%
# Download
# !git clone https://gitlab.com/UOC/eimt/prog_datasci_2/activities/Activity_{activity_number}.git
# Out:
# Cloning into 'Activity_1'...
# remote: Enumerating objects: 339, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 339 (delta 3), reused 12 (delta 1), pack-reused 318 (from 1)
# Receiving objects: 100% (339/339), 24.78 MiB | 10.96 MiB/s, done.
# Resolving deltas: 100% (120/120), done.

# %% [markdown]
# You can now find your activity in the folder that you have indicated, within a subfolder called "activity_i" where i is the activity number. Remember to save your work frequently and submit your work when you are done in the proper "activity" tab in UOC's webpage.

# %% [markdown]
# # Download practice solution
#
# Two weeks after the final date of delivery of the practical, the download of the solution of the practical will be enabled.
#
# *Remember to create a folder to separate the materials from the activities and their solutions.*

# %%
# enter activity number
activity_number = 1

# %%
# Download
# !git clone https://gitlab.com/UOC/eimt/prog_datasci_2/activities/activity_sol_{activity_number}.git
# Out:
# Cloning into 'activity_sol_1'...
# fatal: could not read Username for 'https://gitlab.com': No such device or address
