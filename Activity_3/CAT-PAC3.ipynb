# %% [markdown]
# <div style="width: 100%; clear: both;">
#     <div style="float: left; width: 50%;">
#        <img src="http://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/UOC_Masterbrand.jpg", align="left">
#     </div>
# </div>
#
# <div style="float: right; width: 50%;">
#     <p style="margin: 0; padding-top: 22px; text-align:right;">22.403 · Programació per a la ciència de dades</p>
#     <p style="margin: 0; text-align:right;">Grau en Ciència de Dades Aplicada</p>
#     <p style="margin: 0; text-align:right; padding-button: 100px;">Estudis d'Informàtica, Multimèdia i Telecomunicació</p>
# </div>
#
# </div>
# <div style="width: 100%; clear: both;">
# <div style="width:100%;">&nbsp;</div>

# %% [markdown]
# Programació per a la ciència de dades - PAC3
# ============================
#
# En aquest Notebook trobareu un conjunt d'exercicis que suposen la tercera activitat d'avaluació continuada (PAC) de l'assignatura.
#
# Per a cada exercici, tingueu en compte que:
# * **És necessari incloure comentaris** del vostre codi, que expliquin com heu implementat la solució del problema plantejat.
# * **És imprescindible** citar les referències que heu consultat per a realitzar l'activitat.
# * **Es valorarà** que el codi proporcionat solucioni el problema proposat i també la qualitat del codi (comentaris, llegibilitat, claredat, ús de les estructures de dades adequades, bona nomenclatura de les variables i funcions, seguiment del PEP8, etc.).
#
# Veureu que totes les activitats tenen una etiqueta, que indica els recursos necessaris per tal de dur-la a terme. Hi ha tres possibles etiquetes:
#
# * <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 3px; ">NM</span> **Només materials**: les eines necessàries per a realitzar l'activitat es poden trobar als materials de l'assignatura (considerarem també els materials de l'assignatura Fonaments de Programació, així com les lectures obligatòries de material extern que s'indiquen als notebooks).
#
# * <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span> **Consulta externa guiada**: l'activitat pot requerir fer ús d'eines que no es troben als materials de l'assignatura, però l'enunciat conté indicacions d'on o com trobar la informació addicional necessària per resoldre l'activitat.
#
# * <span style="font-family: Courier New; background-color: #f2ae72; color: #000000; padding: 3px; ">EI</span> **Consulta externa independent**: l'activitat pot requerir fer ús d'eines que no es troben als materials de l'assignatura, i l'enunciat pot no incloure la descripció d'on o com trobar aquesta informació addicional. Caldrà que l'estudiant busqui aquesta informació fent servir els recursos que s'han explicat a l'assignatura.
#
# És important notar que aquestes etiquetes no indiquen el nivell de dificultat de l'exercici, sinó únicament la necessitat de consulta de documentació externa per a la seva resolució. A més, recordeu que les **etiquetes són informatives**, però **podeu consultar referències externes, i usar-les, sempre que vulgueu (encara que no s'indiqui explícitament) o pot ser que pugueu fer una activitat sense consultar cap mena de documentació**. Per exemple, per resoldre una activitat que només requereixi els materials de l'assignatura, podeu consultar referències externes si voleu, ja sigui tant per ajudar-vos en la reva resolució com per ampliar el coneixement!
#
# **Important**: A més de la puntuació de cada exercici, que valora la qualitat de la solució que proposeu i els resultats obtinguts, en aquesta PAC es valoren 3 aspectes addicionals, transversals a totes les activitats:
#
# * **Documentació** (**0.25*f punts**): Totes les funcions del exercicis d’aquesta PAC hauran de ser correctament documentades utilitzant docstrings (en el format que preferiu).
#
# * **Modularitat** (**0.5*f punts**): Es valorarà la modularitat del codi (la correcta estructuració del codi en funcions).
#
# * **Estil** (**0.25*f punts**): El codi ha de seguir la guia d'estil de Python [PEP8](https://www.python.org/dev/peps/pep-0008/), exceptuant els casos on fer-ho compliqui la llegibilitat del codi.
#
# On $f$ es la fracció de la PAC realitzada. És a dir, la nota d'aquests aspectes transversals serà proporcional a la part de la PAC realitzada.
#
# Així, els aspectes transversals tindran una puntuació màxima d'1 punt si es lliuren tots els exercicis de la PAC. En cas contrari, la nota d'aspectes transversals es multiplicarà per la fracció de la PAC lliurada. Per exemple, si els aspectes transversals estan puntuats amb un 1 i només hi ha la meitat de la PAC lliurada, la nota dels aspectes transversals serà $1*0.5=0.5$.
#
# La nota dels aspectes transversals es considera inclosa en les notes esmentades per als exercicis.

# %% [markdown]
# ---
#
# ## Abans de començar
#
# Si us plau, llegiu antentament els següents paràgrafs relatius a la originalitat en les activitats de l'assignatura abans de començar a treballar en la PAC. Si teniu qualsevol dubte, dirigiu-vos al professor col·laborador de l'aula abans de seguir amb l'activitat.
#
# <div class="alert alert-block alert-success">La manca d’originalitat es produeix quan en una activitat hi apareix contingut que no ha estat elaborat de forma individual per l’estudiant i no es referencia adequadament el seu origen. O bé quan, encara que el contingut extern estigui referenciat, aquest és tan extens que no és possible considerar a l’estudiant l’autor o autora de l’activitat.
# <br /><br />
# Així, alguns exemples de comportaments inadequats són pel que fa a la manca d'originalitat són:
# <ol>
#     <li>Crear la solució d'un exercici de la PAC en col·laboració entre diversos estudiants.</li>
#     <li>Incloure un exercici de la PAC que utilitzi codi trobat a internet sense citar-ne la font.</li>
#     <li>Compartir la vostra solució de la PAC amb altres estudiants de l'assignatura.</li>
#     </ol>
# </div>
#
# ## Instruccions de lliurament
#
# Per tal de lliurar l'activitat és necessari que feu els següents passos:
#
# 1. Comproveu que el notebook s'executa correctament. És important que abans de lliurar la vostra PAC comproveu que la versió final del codi que lliureu s'executa correctament en la seva totalitat. Per fer-ho, us recomanem fer una execució completa des de zero del notebook: feu click a *Kernel > Restart & Run All* i comproveu que el notebook s'executa correctament.
# 2. Confirmeu que sou els autors únics de la PAC i que aquesta inclou totes les cites a recursos externs que s'hagin utilitzat per a elaborar-la. Per tal de confirmar que sou els autors únics de l'activitat, afegiu el vostre nom complet al paràgraf de la cel·la següent.
# 3. Genereu un arxiu comprimit que inclogui tots els fitxers de la PAC (tant el fitxer amb el notebook, amb extensió .ipynb, com les carpetes amb les dades que calguin per a executar-lo). Assegureu-vos que es pot descomprimir aquest fitxer en qualsevol directori de l'ordinador i que el codi s'executa sense problemes.
# 5. Lliureu la PAC a través del Registre d'Avaluació Continuada de l'aula.

# %% [markdown]
# <div class="alert alert-block alert-warning">Jo, Jonathan Mir Fernández-Aramburu, confirmo que he elaborat de manera individual totes les activitats resoltes en aquesta PAC i que he inclòs les cites a totes les fonts externes que he utilitzat per a resoldre les activitats. </div>

# %% [markdown]
# Tal com s’ha comentat abans, en aquesta PEC es valora i es puntua seguir la guia d’estil de Python **PEP8**. Tot i així, no és necessari activar les alertes d’estil amb **pycodestyle**. S’entén que l’alumne, en aquest punt, ja ha de seguir les regles d’estil que afavoreixen la llegibilitat del codi.

# %% [markdown]
# ## Exercici 1
#
# En aquesta sèrie d’exercicis treballarem amb l’ordre de creixement de diferents funcions, un concepte fonamental per analitzar l’eficiència dels algorismes.
#
# L’anàlisi asimptòtica permet estudiar com evoluciona el temps d’execució d’un algorisme en funció de la mida de l’entrada, deixant de banda detalls concrets d’implementació o del maquinari utilitzat.
#
# Comprendre el creixement de les funcions permet avaluar la complexitat dels algorismes i estimar-ne el comportament a mesura que augmenta la mida de l’entrada, i serveix com a base per a anàlisis posteriors orientades a la seva millora o optimització.

# %% [markdown]
# <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 3px; ">NM</span> **Exercici 1.1 (0.5 punts)**
#
# Quan s’analitza la complexitat d’un algorisme en funció del creixement del seu temps d’execució, s’utilitzen diferents termes.
#
# Indiqueu breument, per a cadascuna de les funcions següents, quin terme s’utilitza habitualment en l’anàlisi d’algorismes per descriure el seu tipus de creixement.
#
# Considereu les funcions següents:
#
# - $n\log(n)$
# - $e^n$
# - $n!$
# - $\log(n)$
# - $n$
# - $2n^2 + 3n + 4$
# - $1^n$

# %% [markdown]
# >- $n\log(n)$: Creixement quasi-lineal
# >- $e^n$: Creixement exponencial
# >- $n!$: Creixement factorial
# >- $\log(n)$: Creixement logarítmic
# >- $n$: Creixement lineal
# >- $2n^2 + 3n + 4$: Creixement quadràtic
# >- $1^n$: Creixement constant
# >
# > **Font:**
# > *Unitat 4. Optimització, complexitat i profiling 2.2.3 Notacions i definicions formals*

# %% [markdown]
# <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 3px; ">NM</span> **Exercici 1.2 (0.5 punts)**
#
# Ordeneu les funcions de l’apartat anterior de menor a major segons el seu ordre de creixement.

# %% [markdown]
# >1. $1^n$
# >1. $\log(n)$
# >1. $n$
# >1. $n\log(n)$
# >1. $2n^2 + 3n + 4$
# >1. $e^n$
# >1. $n!$
# >
# > **Font:**
# > *Unitat 4. Optimització, complexitat i profiling 2.2.3 Notacions i definicions formals*

# %% [markdown]
# <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 3px; ">NM</span> **Exercici 1.3 (0.5 punts)**
#
# En aquest exercici heu d’identificar quins parells de funcions presenten un ordre de creixement similar entre els dos conjunts següents.
#
# **Conjunt A**
#
# - $n^2$
# - $\log(n)$
# - $n\log(n)$
# - $2^n$
# - $n$
# - $n!$
#
# **Conjunt B**
#
# - $n\log(n^2)$
# - $3n$
# - $e^n$
# - $\log(n^2)$
# - $n^2 + n$
# - $(n+1)!$
#
# Justifiqueu breument per què ambdues funcions presenten el mateix ordre de creixement asimptòtic.

# %% [markdown]
# >
# >- $n^2$ i $n^2 + n$ tenen el mateix ordre de creixement perquè, quan $n$ creix, el terme dominant és $n^2$. El terme lineal $n$ es llavors negligible. Per tant, $n^2 + n \in \Theta(n^2)$.
# >
# >- $\log(n)$ i $\log(n^2)$ tenen el mateix ordre perquè $\log(n^2) = 2\log(n)$. El factor constant 2 no afecta l’ordre de creixement, així que $\log(n^2) \in \Theta(\log(n))$.
# >
# >- $n\log(n)$ i $n\log(n^2)$ tenen el mateix ordre perquè $n\log(n^2) = n \cdot 2\log(n) = 2n\log(n)$.
# >  Novament, el factor constant 2 no modifica el creixement asimptòtic. Per tant, $n\log(n^2) \in \Theta(n\log(n))$.
# >
# >- $n$ i $3n$ tenen el mateix ordre perquè només es diferencien per una constant multiplicativa. Així, $3n \in \Theta(n)$.
# >
# >- $2^n$ i $e^n$ són totes dues funcions de creixement exponencial. En termes generals d’anàlisi d’algorismes, pertanyen al mateix tipus de creixement: exponencial. Tanmateix, no són asumptòticament equivalents en sentit estricte.
# >
# >- $n!$ i $(n+1)!$ són totes dues funcions de creixement factorial, ja que
# >  $(n+1)! = (n+1)n!$
# >  Per tant, totes dues representen un creixement factorial, molt més ràpid que qualsevol funció polinòmica o exponencial simple, tot i que de la mateixa manera que el punt anterior, no són dues funcions equivalents en el sentit estricte
# >
# > **Font:**
# > *Unitat 4. Optimització, complexitat i profiling 2.2.3 Notacions i definicions formals*

# %% [markdown]
# ## Exercici 2
#
# En aquest apartat analitzarem l’eficiència temporal de diferents fragments de codi.
#
# L’objectiu és comprendre com la mida de l’entrada afecta el temps d’execució d’un algorisme i aprendre a identificar possibles ineficiències en la seva implementació.
#
# Recordeu que, en analitzar l’eficiència d’un algorisme, normalment es considera el **pitjor cas**, és a dir, aquell en què l’algorisme requereix el major nombre d’operacions per completar-se.

# %% [markdown]
# <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span> **Exercici 2.1 (0.75 punts)**
#
# Indiqueu la complexitat algorísmica $\Theta$ en relació amb el temps d’execució del fragment de codi següent, justificant la vostra resposta.

# %%
def extract_active_bits(x: int) -> int:
    """
    Compute the number of active bits in the binary 
    representation of an int.

    Args:
        x (int): Input integer.

    Returns:
        int: Number of active bits.
    """
    count: int = 0
    value: int = x

    while value > 1:
        bit: int = value % 2
        value = value // 2

        if bit == 1:
            count += 1

    if value == 1:
        count += 1

    return count

# %% [markdown]
# >A cada iteració, value es divideix entre 2 mitjançant divisió entera. Per tant, el nombre d’iteracions no creix linealment amb x, sinó amb el nombre de vegades que podem dividir x entre 2 fins arribar a 1, patró que correspon a la funció $\log_2(x)$
# >
# >La resta d’operacions dins del bucle tenen cost constant, i les instruccions finals també són constants. Per això, el temps d’execució ve determinat pel nombre d’iteracions del while.
# >
# > **Font:**
# > *Unitat 4. Optimització, complexitat i profiling 2.2.3 Notacions i definicions formals*

# %% [markdown]
# <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span> **Exercici 2.2 (0.75 punts)**
#
# En aquest exercici també analitzareu un fragment de codi amb l’objectiu de detectar possibles ineficiències i comprendre la seva complexitat temporal.
#
# Justifiqueu breument l’anàlisi de l’algorisme, indiqueu-ne la complexitat temporal i comenteu on es troba la principal ineficiència del codi.
#
# **Nota:**
# - En aquest exercici podeu assumir que la dimensió dels embeddings és fixa (per exemple, **1408**).

# %%
def find_most_similar(query: list[float], embeddings: list[list[float]]) -> int:
    """
    Find the index of the most similar embedding using squared 
    Euclidean distance.

    Args:
        query (list[float]): Query embedding.
        embeddings (list[list[float]]): Database of embeddings.

    Returns:
        int: Index of the most similar embedding.
    """
    best_index = -1
    best_distance = float("inf")

    for i in range(len(embeddings)):
        distance = 0.0

        for j in range(len(query)):
            diff = query[j] - embeddings[i][j]
            distance += diff * diff

        if distance < best_distance:
            best_distance = distance
            best_index = i

    return best_index

# %% [markdown]
# >La complexitat temporal de la funció és:
# >
# >$\Theta(n)$
# >
# >on $n$ és el nombre d’embeddings.
# >
# >La funció recorre tots els embeddings de la base de dades i, per a cadascun, calcula la distància euclidiana quadrada respecte de l’embedding de consulta. Aquest càlcul fa servir un bucle intern que recorre totes les components del vector. Ara bé, com que l’enunciat indica que la dimensió dels embeddings és fixa, aquest cost es pot considerar constant. Per tant, el temps d’execució creix linealment amb el nombre d’embeddings.
# >
# >La ineficiència principal del codi és que el bucle intern sobre les dimensions utilitza llistes Python i un bucle _for_ pur en lloc d'operacions vectoritzades de NumPy:
# >
# ```python
# for j in range(len(query)):
#     diff = query[j] - embeddings[i][j]
#     distance += diff * diff
# ```
# >
# >La complexitat general seria:
# >
# >$(\Theta(n \cdot d))$
# >
# >on $d$ és la dimensió de cada embedding.
# >
# >Però si $d$ és fixa, queda:
# >
# >$(\Theta(n))$
# >
# > **Font:**
# > *Unitat 4. Optimització, complexitat i profiling 2.2.3 Notacions i definicions formals*

# %% [markdown]
# ## Exercici 3
#
# En aquest exercici detectareu les ineficiències i millorareu el codi.

# %% [markdown]
# <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 3px; ">NM</span> **Exercici 3.1 (1 punt)**
#
# Utilitzant les eines de *profiling* que hem vist al Notebook de teoria, analitzeu el fragment de codi ineficient següent i identifiqueu quin és el coll d’ampolla de l’algorisme.
#
# Per fer-ho, heu de dur a terme el següent:
#
# - Genereu una llista d’enters (10.000 elements) per poder analitzar el rendiment de l’algorisme.
#
# - Analitzeu el rendiment de la funció utilitzant `%timeit` i `%lprun`.
#
# - A partir dels resultats obtinguts amb ambdues eines, identifiqueu quina part de l’algorisme constitueix el coll d’ampolla i expliqueu les ineficiències detectades, relacionant-les amb els resultats obtinguts mitjançant el *profiling*.
#
# - Indiqueu quina és la complexitat temporal aproximada de l’algorisme i justifiqueu la vostra resposta.

# %%
from typing import List, Dict

def compute_frecs(values: List[int]) -> Dict[int, int]:
    """
    Computes the frequency of each value in the input list.

    Args:
        values: List of integer values.

    Returns:
        Dictionary mapping each value to its frequency.
    """
    frecs: Dict[int, int] = {}
    for j in range(len(values)):
        current_value = values[j]
        count = 0
        for k in range(len(values)):
            if values[k] == current_value:
                count += 1
        frecs[current_value] = count
    return frecs

# %%
import random

# Generem una llista de 10.000 números aleatoris compresos entre 0 i 1000
values = [random.randint(0, 1000) for _ in range(10000)]

# Apliquem la funció compute_frecs
# %timeit compute_frecs(values)

# Analitzem el rendiment mitjançant el mòdul line_profiler aplicant la llista anterior sobre la funció d'estudi
# %load_ext line_profiler
# %lprun -f compute_frecs compute_frecs(values)
# Out:
# 4.28 s ± 294 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Timer unit: 1e-07 s
#
# Total time: 45.6295 s
# File: C:\Users\e103784\AppData\Local\Temp\ipykernel_15316\282275511.py
# Function: compute_frecs at line 3
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#      3                                           def compute_frecs(values: List[int]) -> Dict[int, int]:
#      4                                               """
#      5                                               Computes the frequency of each value in the input list.
#      6
#      7                                               Args:
#      8                                                   values: List of integer values.
#      9
#     10                                               Returns:
#     11                                                   Dictionary mapping each value to its frequency.
#     12                                               """
# ...

# %% [markdown]
# >Els resultats de profiling mostren que el coll d’ampolla principal es troba en el bucle intern de la funció compute_frecs, >concretament en aquesta part:
# >
# ```python
# for k in range(len(values)):
#     if values[k] == current_value:
#         count += 1
# ```
# >
# >Per cada element de la llista, l’algorisme torna a recórrer tota la llista per comptar quantes vegades apareix aquell valor. Això provoca moltes comparacions repetides, especialment quan hi ha valors duplicats, ja que es recalcula la freqüència d’un mateix nombre diverses vegades.
# >
# >Amb %timeit es pot observar que el temps d’execució és elevat per a una llista de 10.000 elements. Amb %lprun es pot veure que la major part del temps es concentra dins del segon bucle, on es fan les comparacions ```values[k] == current_value.```
# >
# >La complexitat temporal aproximada de l’algorisme és Θ(n²), on _n_ és la mida de la llista. Això és així perquè hi ha un bucle extern que recorre els n elements i, per cada iteració, un bucle intern que torna a recórrer els _n_ elements. Per tant, el nombre total d’operacions creix aproximadament com $ n · n = n^2$.
# >
# > **Font:**
# > *Unitat 4. Optimització, complexitat i profiling - 2. Anàlisi d'algorismes; 3.1. Profiling del temps d'execució d'un programa*

# %% [markdown]
# <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span> **Exercici 3.2 (0.5 punts)**
#
# En aquest exercici heu de millorar l’algorisme `compute_frecs` amb l’objectiu de reduir-ne el temps d’execució i millorar-ne l’eficiència.
#
# Per fer-ho, creeu una nova funció anomenada `compute_frecs_improved` i implementeu el codi corresponent.
#
# A més, heu de:
# - Mesureu el temps d’execució de `compute_frecs_improved` utilitzant `%timeit`, compareu-lo amb l’obtingut anteriorment per a `compute_frecs` i calculeu l’*speed-up* de la versió optimitzada respecte de l’original.
# - Expliqueu quina millora heu introduït respecte de la versió original de l’algorisme.
# - Indiqueu quina és la complexitat temporal aproximada de la nova versió.

# %%
from typing import List, Dict

def compute_frecs_improved(values: List[int]) -> Dict[int, int]:
    """
    Computes the frequency of each value in the input list.

    Args:
        values: List of integer values.

    Returns:
        Dictionary mapping each value to its frequency.
    """
    frecs: Dict[int, int] = {}

    for value in values:
        if value in frecs:
            frecs[value] += 1
        else:
            frecs[value] = 1

    return frecs

# %%
# Font: Unitat 4. Optimització, complexitat i profiling 
# 3.1.4 L'ús del profiling per optimitzar implementacions 

import timeit

# Mesurem el temps d'execució de la funció original
temps_original = timeit.timeit(
    lambda: compute_frecs(values),
    number=10
)

# Mesurem el temps d'execució de la funció millorada
temps_millorat = timeit.timeit(
    lambda: compute_frecs_improved(values),
    number=10
)

# Calculem el rati de millora entre les dues mesures anteriors i imprimim resultats
speed_up = temps_original / temps_millorat

print(f"Temps original: {temps_original:.6f} s")
print(f"Temps millorat: {temps_millorat:.6f} s")
print(f"Speed-up: {speed_up:.2f}x")
# Out:
# Temps original: 33.776021 s
# Temps millorat: 0.007764 s
# Speed-up: 4350.56x

# %% [markdown]
# >La millora introduïda consisteix a comptar les freqüències en una sola passada per la llista. En la versió original, per cada element es tornava a recórrer tota la llista per comptar quantes vegades apareixia, cosa que provocava moltes comparacions repetides.
# >
# >En canvi, la funció compute_frecs_improved utilitza un diccionari per anar acumulant el nombre d’aparicions de cada valor. Si el valor ja existeix al diccionari, s’incrementa el seu comptador; si no existeix, s’inicialitza a 1.
# >
# >La complexitat temporal aproximada de la nova versió és Θ(n), on n és el nombre d’elements de la llista. Això és així perquè la funció només recorre la llista una vegada i les operacions d’accés i actualització del diccionari tenen cost constant de mitjana.
# >
# >Per tant, respecte de la versió original, que tenia complexitat Θ(n²), aquesta versió és molt més eficient.
# >
# > **Font:**
# > *Unitat 4. Optimització, complexitat i profiling - 2. Anàlisi d'algorismes; 3.1. Profiling del temps d'execució d'un programa*

# %% [markdown]
# <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span> **Exercici 3.3 (0.5 punts)**
#
# Quan optimitzem un algorisme n’estem modificant la implementació, però és fonamental assegurar-se que el comportament funcional no canvia. A més, també és important visualitzar la millora en el rendiment, ja que moltes vegades les optimitzacions s’entenen millor en observar com canvia el temps d’execució.
#
# En aquest apartat heu de dur a terme el següent:
#
# - **Verificació de resultats:** comproveu que ambdues implementacions (`compute_frecs` i `compute_frecs_improved`) produeixen el mateix resultat utilitzant diverses llistes d’entrada. Per fer-ho, afegiu comprovacions amb `assert` que comparin les sortides de totes dues funcions.
#     - Utilitzeu:
#     ```python
#     values1 = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]
#     values2 = [10, 5, 10, 3, 5, 3, 3, 8, 8, 8, 1, 1, 1]
#     ```
#
# - **Comparació del rendiment:** genereu llistes de diferents mides i mesureu el temps d’execució de tots dos algorismes. Representeu els resultats en una gràfica que mostri com creix el temps d’execució en funció de la mida de la llista \(n\).
#     - Utilitzeu la llista següent:
#     ```python
#     sizes = [200, 300, 500, 750, 1200, 3000]
#     ```

# %%
# Generem les dues llistes de l'enunciat
values1 = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]
values2 = [10, 5, 10, 3, 5, 3, 3, 8, 8, 8, 1, 1, 1]

# Verifiquem que els resultats de les dues funcions sobre les dues llistes són els mateixos
assert compute_frecs(values1) == compute_frecs_improved(values1)
assert compute_frecs(values2) == compute_frecs_improved(values2)

print("Les dues funcions produeixen el mateix resultat.")
# Out:
# Les dues funcions produeixen el mateix resultat.

# %%
import matplotlib.pyplot as plt

# Generem el llistat amb les mides definides a l'enunciat
sizes = [200, 300, 500, 750, 1200, 3000]

# Inicialitzem les llistes que emmagatzemaran els resultats de 
# les mesures de temps per cada execució
times_original = []
times_improved = []

# Generem un bucle d'execució per a cada mida
for size in sizes:
    # Generem tants elements com indicats per la variable size, amb un valor 
    # aleatori entre 0 i 1000
    values = [random.randint(0, 1000) for _ in range(size)]

    # Mesurem el temps  d'execució de la funció original sobre la llista values
    time_original = timeit.timeit(
        lambda: compute_frecs(values),
        number=1
    )

    # Mesurem el temps  d'execució de la funció millorada sobre la llista values
    time_improved = timeit.timeit(
        lambda: compute_frecs_improved(values),
        number=100
    ) / 100

    # Guardem a les llistes inicialitzades a l'inici els temps 
    # d'execució de la funció original i millorada
    times_original.append(time_original)
    times_improved.append(time_improved)


# Grafiquem els resultats de la relació entre el tamany de la llista 
# d'entrada i el temps d'execució en una gràfica de linies

plt.plot(sizes, times_original, marker="o", label="compute_frecs")
plt.plot(sizes, times_improved, marker="o", label="compute_frecs_improved")

plt.xlabel("Mida de la llista (n)")
plt.ylabel("Temps d'execució (segons)")
plt.title("Comparació del temps d'execució")
plt.legend()
plt.show()

# %% [markdown]
# >Les comprovacions amb assert confirmen que les dues funcions produeixen el mateix resultat per a diferents llistes d’entrada. Això permet verificar que l’optimització no ha modificat el comportament funcional de l’algorisme.
# >
# >La gràfica mostra que el temps d’execució de compute_frecs creix molt més ràpidament que el de compute_frecs_improved. Això és degut al fet que la versió original utilitza dos bucles imbricats i té una complexitat aproximada Θ(n²), mentre que la versió millorada només recorre la llista una vegada i té complexitat Θ(n).
# >
# >Per tant, la versió optimitzada manté el mateix resultat però redueix significativament el temps d’execució.
# >
# >**Fonts:**
# >*Unitat 4. Optimització, complexitat i profiling - 2. Anàlisi d'algorismes; 3.1. Profiling del temps d'execució d'un programa*

# %% [markdown]
# ## Exercici 4
#
# En aquest exercici treballarem amb el mòdul `multiprocessing` per comparar l’execució seqüencial amb la paral·lela d’una mateixa tasca computacional.

# %% [markdown]
# <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span> **Exercici 4.1 (1 punt)**
#
# Es proporciona una funció que, donada una imatge en escala de grisos representada mitjançant una matriu, compta quants píxels tenen un valor superior a un determinat llindar. A partir d’aquesta funció ja implementada, es demana desenvolupar dues noves funcions:
#
# - **Versió seqüencial:** implementeu una funció que rebi una llista d’imatges i apliqui seqüencialment la funció `count_white_pixels()`, mesurant i mostrant el temps total d’execució en segons.
#
# - **Versió amb multiprocessament:** implementeu una altra funció que realitzi el mateix càlcul, però utilitzant múltiples processos mitjançant el mòdul `multiprocessing`, mostrant també el temps total d’execució.
#
# Ambdues funcions hauran d’utilitzar la mateixa llista d’entrada i permetre comparar el rendiment entre l’execució seqüencial i la paral·lela. Per fer-ho, també es proporciona el llistat de matrius, que simulen imatges de diferents mides i que s’haurà d’utilitzar com a entrada comuna en ambdues implementacions.
#
# **IMPORTANT**: depenent del sistema i de l’entorn d’execució, el multiprocessament pot no funcionar correctament directament en un notebook. Si això passa, hauràs de moure les funcions a un mòdul de Python independent (.py).

# %%
import numpy as np
import multiprocessing as mp

def count_white_pixels(image: np.ndarray, threshold: int = 200) -> int:
    """
    Counts how many pixels in a grayscale image are greater than a 
    given threshold.

    Args:
        image (np.ndarray): Image represented as a 2D NumPy array.
        threshold (int): Threshold value used to determine whether 
        a pixel is considered white.

    Returns:
        int: Number of pixels greater than the threshold.
    """
    count = 0
    rows, cols = image.shape

    for i in range(rows):
        for j in range(cols):
            if image[i, j] > threshold:
                count += 1

    return count


images = [
    np.random.randint(0, 256, (2000, 2000), dtype=np.uint8),
    np.random.randint(0, 256, (2500, 2500), dtype=np.uint8),
    np.random.randint(0, 256, (3000, 3000), dtype=np.uint8),
    np.random.randint(0, 256, (3500, 3500), dtype=np.uint8),
]

# %%
# Fonts: Unitat 5: Optimització de codi: programació concurrent i paral·lela
# 3.1. Introducció al multiprocessament
# 3.2. Optimització de codi fent servir multiprocés
# 3.3.1. Variables compartides
# 3.3.2. Comunicació entre processos

import importlib
import pixel_counter
importlib.reload(pixel_counter)

# Les funcions count_white_pixels_sequential i count_white_pixels_parallel
# es troben al fitxer pixel_counter.py. S'han separat del notebook perquè
# el context "spawn" de multiprocessing a Windows requereix que les funcions
# estiguin en un mòdul independent amb el guard if __name__ == "__main__".
# Font: https://docs.python.org/3/library/multiprocessing.html#contexts-and-start-methods
from pixel_counter import count_white_pixels_sequential, count_white_pixels_parallel

# %%
# Verifiquem que ambdues funcions produeixen el mateix resultat

results_seq = count_white_pixels_sequential(images)
results_par = count_white_pixels_parallel(images)

assert results_seq == results_par

print("Les dues versions produeixen el mateix resultat.")
# Out:
# Temps seqüencial: 5.3638 segons
# Temps paral·lel: 3.5843 segons
# Les dues versions produeixen el mateix resultat.

# %% [markdown]
# <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span> **Exercici 4.2 (1 punt)**
#
# En aquest apartat s’analitzarà el comportament del programa en executar-se de manera seqüencial i en executar-se mitjançant processament en paral·lel.
#
# - A partir dels resultats obtinguts, és millor la versió paral·lela que la seqüencial?
#
# - Identifica i explica els costos addicionals associats a l’ús de multiprocessament.
#
# - En quines situacions una execució paral·lela pot resultar més lenta que una de seqüencial?

# %% [markdown]
# > A partir dels resultats obtinguts, la versió paral·lela és millor que la seqüencial ja que el temps d'execució en paral·lel és menor que el temps seqüencial. Per tant podem dir que el multiprocessament ha aportat una millora.
# >
# >L’ús de multiprocessament té diversos costos addicionals. En primer lloc, cal crear els processos, cosa que té un cost inicial. En segon lloc, les dades s’han de repartir entre els processos. En aquest exercici, les imatges són matrius grans de NumPy, de manera que enviar-les als processos pot implicar còpies de dades i consum addicional de memòria. També hi ha un cost de comunicació per retornar els resultats al procés principal i un cost de coordinació per repartir les tasques i sincronitzar-ne la finalització.
# >
# >Una execució paral·lela pot resultar més lenta que una de seqüencial quan les tasques són petites o molt ràpides, perquè el cost de crear processos i transferir dades pot ser superior al temps que s’estalvia. També pot passar quan hi ha poques tasques en comparació amb el nombre de processos, quan les dades que s’han de passar als processos són molt grans, quan hi ha limitacions de memòria o quan l’entorn d’execució, com ara un notebook, afegeix sobrecost o problemes amb multiprocessing.
# >
# >Per tant, la versió paral·lela només és clarament avantatjosa quan cada tasca té prou càrrega computacional i el cost de repartir el treball entre processos queda compensat per l’execució simultània.
# >
# >**Fonts:**
# >*Unitat 5: Optimització de codi: programació concurrent i paral·lela - 3.2. Optimització de codi fent servir multiprocés*

# %% [markdown]
# ## Exercici 5
#
# Una empresa dedicada al comerç electrònic us ha sol·licitat desenvolupar un sistema de recopilació d’informació de productes des d’una API pública. Cada recurs s’obté en format JSON i inclou informació descriptiva del producte, així com valors numèrics com el preu, el descompte, la valoració o l’estoc.
#
# L’objectiu és descarregar aquests recursos, emmagatzemar-los localment i avaluar el rendiment del procés utilitzant diferents estratègies d’execució.
#
# Per facilitar l’accés a les dades, se us proporcionen les funcions base següents. La primera genera una llista d’URL corresponents a 75 productes de l’API pública, i la segona mostra com descarregar un únic recurs JSON i emmagatzemar-lo localment.

# %%
def get_json_urls(num: int = 75) -> list[str]:
    """
    Generates a list of product JSON URLs from the API.

    Args:
        num: Number of product URLs to generate.

    Returns:
        A list of product JSON URLs.
    """
    return [f"https://dummyjson.com/products/{i}" for i in range(1, num + 1)]

# %%
import json
import requests

def download_json(url: str, output_path: str) -> None:
    """
    Downloads a JSON resource from a URL and saves it locally.

    Args:
        url: URL of the JSON resource.
        output_path: Local path where the JSON file will be stored.
    """
    response: requests.Response = requests.get(url, timeout=10)
    response.raise_for_status()

    data: dict = response.json()

    # Save JSON content into a local file
    with open(output_path, "w", encoding="utf-8") as file:
        json.dump(data, file, indent=4, ensure_ascii=False)

# %% [markdown]
# <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span> **Exercici 5.1 (0.5 punts)**
#
# Implementeu una versió seqüencial del sistema de descàrrega de productes en format JSON.
#
# Per fer-ho, heu d’obtenir una llista d’URL de productes des d’una API pública i recórrer-la una a una, descarregant cada recurs i emmagatzemant-lo localment en una carpeta, per exemple, `products/`.
#
# Cada fitxer s’haurà de desar amb un nom únic, com ara `product_1.json`, `product_2.json`, etc.
#
# Durant el procés, heu de:
#
# - Mesurar i mostrar el temps total d’execució de la descàrrega seqüencial,
# - Indicar quants productes s’han descarregat correctament.

# %%
# Fonts: Unitat 5: Optimització de codi: programació concurrent i paral·lela
# 2.2. Optimització de codi fent servir threads en Python

import os
import time

def download_products_sequential(num_products: int = 75, output_dir: str = "products") -> int:
    """
    Descarrega els JSON files de forma sequencial i els emmagatzema localment

    Args:
        num_products: Nombre d'arxius JSON de productes a descarregar
        output_dir: Directori on es guardaran els fitxers

    Returns:
        int: Nombre d'arxius JSON de productes descarregats correctament
    """

    # En cas de que no existeixi el directori, el creem
    os.makedirs(output_dir, exist_ok=True)

    # Generem la llista d'URLs dels productes a descarregar
    urls = get_json_urls(num_products)

    # Inicialitzem el comptador de descàrregues correctes
    downloaded = 0

    # Iniciem el cronòmetre per mesurar el temps total d'execució
    start_time = time.perf_counter()

    # Iterem sobre cada URL assignant-li un índex a partir de 1
    for i, url in enumerate(urls, start=1):
        # Construïm la ruta de sortida per al fitxer JSON del producte
        output_path = os.path.join(output_dir, f"product_{i}.json")

        try:
            # Descarreguem el JSON i el guardem localment
            download_json(url, output_path)
            # Incrementem el comptador si la descàrrega ha estat correcta
            downloaded += 1
        except requests.RequestException as error:
            # Mostrem l'error si la descàrrega ha fallat i continuem amb la següent URL
            print(f"Error descarregant {url}: {error}")

    # Calculem el temps total transcorregut des de l'inici
    total_time = time.perf_counter() - start_time

    # Mostrem el resum d'execució: temps total i productes descarregats
    print(f"Temps total d'execució seqüencial: {total_time:.4f} segons")
    print(f"Productes descarregats correctament: {downloaded}")

    # Retornem el nombre de productes descarregats correctament
    return downloaded

# %%
downloaded_products = download_products_sequential()
# Out:
# Error descarregant https://dummyjson.com/products/1: HTTPSConnectionPool(host='dummyjson.com', port=443): Max retries exceeded with url: /products/1 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)')))
# Error descarregant https://dummyjson.com/products/2: HTTPSConnectionPool(host='dummyjson.com', port=443): Max retries exceeded with url: /products/2 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)')))
# Error descarregant https://dummyjson.com/products/3: HTTPSConnectionPool(host='dummyjson.com', port=443): Max retries exceeded with url: /products/3 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1081)')))
# ...

# %% [markdown]
# <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span> **Exercici 5.2 (1 punt)**
#
# Implementeu una versió concurrent del sistema de descàrrega de productes.
#
# Per fer-ho, heu de reutilitzar la lògica de descàrrega de l’exercici anterior i adaptar-la perquè múltiples productes es puguin descarregar de manera concurrent mitjançant la classe `ThreadPoolExecutor`.
#
# Cada fitxer s’haurà de continuar emmagatzemant localment a la carpeta `products/`, utilitzant un nom únic per a cada producte.
#
# Per tant:
#
# - Compareu breument el resultat obtingut amb el temps de la versió seqüencial.
# - Proveu diferents valors per al nombre de threads amb la finalitat de determinar quin ofereix el millor rendiment.
# - Representeu en una gràfica els temps obtinguts per als diferents valors de threads.
# - Indiqueu quin nombre de threads proporciona el millor resultat.
#
# **Nota:**
#
# Podeu provar, per exemple, valors entre 1 i 10 per a `max_workers`.

# %%
# Fonts: Unitat 5: Optimització de codi: programació concurrent i paral·lela
# 2.1. Introducció als threads
# 2.2. Optimització de codi fent servir threads en Python

import os
import time
import requests
import matplotlib.pyplot as plt
from concurrent.futures import ThreadPoolExecutor, as_completed


def download_one_product(index_url: tuple[int, str], output_dir: str = "products") -> bool:
    """
    Downloads a single product JSON file.

    Args:
        index_url: Tuple containing the product index and URL.
        output_dir: Directory where the JSON file will be saved.

    Returns:
        bool: True if the download was successful, False otherwise.
    """
    # Desempaquetem la tupla per obtenir l'índex i la URL del producte
    index, url = index_url
    # Construïm la ruta de sortida amb el nom únic del fitxer
    output_path = os.path.join(output_dir, f"product_{index}.json")

    try:
        # Descarreguem el JSON i el guardem localment
        download_json(url, output_path)
        return True
    except requests.RequestException as error:
        # Capturem errors de xarxa i els mostrem sense aturar les altres descàrregues
        print(f"Error descarregant {url}: {error}")
        return False


def download_products_concurrent(
    num_products: int = 75,
    output_dir: str = "products",
    max_workers: int = 5
) -> tuple[int, float]:
    """
    Downloads product JSON files concurrently using ThreadPoolExecutor.

    Args:
        num_products: Number of product JSON files to download.
        output_dir: Directory where the JSON files will be saved.
        max_workers: Number of threads used by ThreadPoolExecutor.

    Returns:
        tuple[int, float]: Number of successful downloads and total execution time.
    """
    # Creem el directori de sortida si no existeix
    os.makedirs(output_dir, exist_ok=True)

    # Obtenim la llista d'URLs i les combinem amb un índex per identificar cada fitxer
    urls = get_json_urls(num_products)
    indexed_urls = list(enumerate(urls, start=1))

    # Iniciem el cronòmetre per mesurar el temps total de la descàrrega concurrent
    start_time = time.perf_counter()

    # Inicialitzem el comptador de descàrregues correctes
    downloaded = 0

    # Creem un pool de threads amb el nombre de workers indicat
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Enviem totes les tasques de descàrrega al pool de forma concurrent
        futures = [
            executor.submit(download_one_product, index_url, output_dir)
            for index_url in indexed_urls
        ]

        # Recollim els resultats a mesura que les tasques van finalitzant
        for future in as_completed(futures):
            if future.result():
                # Incrementem el comptador per cada descàrrega exitosa
                downloaded += 1

    # Calculem el temps total transcorregut
    total_time = time.perf_counter() - start_time

    # Mostrem el resum d'execució: threads usats, temps total i productes descarregats
    print(f"Threads: {max_workers}")
    print(f"Temps concurrent: {total_time:.4f} segons")
    print(f"Productes descarregats correctament: {downloaded}")

    return downloaded, total_time

# %%
# Definim els valors de threads a provar (de 1 a 10 inclusivament)
thread_values = list(range(1, 11))
# Inicialitzem les llistes per emmagatzemar els temps i descàrregues de cada prova
times = []
downloads = []

# Executem la descàrrega concurrent per a cada nombre de threads i recollim els resultats
for workers in thread_values:
    downloaded, total_time = download_products_concurrent(max_workers=workers)
    downloads.append(downloaded)
    times.append(total_time)

# Creem la figura de la gràfica amb una mida adequada per visualitzar-la
plt.figure(figsize=(8, 5))
# Dibuixem la línia de temps en funció del nombre de threads, amb marcadors als punts
plt.plot(thread_values, times, marker="o")

# Etiquetem els eixos i afegim títol
plt.xlabel("Nombre de threads")
plt.ylabel("Temps d'execució (segons)")
plt.title("Temps de descàrrega segons el nombre de threads")
# Activem la quadrícula per facilitar la lectura dels valors
plt.grid(True)
plt.show()

# Obtenim l'índex del temps mínim per identificar la configuració òptima
best_index = times.index(min(times))
# Recuperem el nombre de threads i el temps corresponent al millor resultat
best_threads = thread_values[best_index]
best_time = times[best_index]

print(f"Millor nombre de threads: {best_threads}")
print(f"Millor temps: {best_time:.4f} segons")

# %%
downloaded_seq = download_products_sequential()
downloaded_conc, time_conc = download_products_concurrent(max_workers=best_threads)
# Out:
# Temps total d'execució seqüencial: 13.0770 segons
# Productes descarregats correctament: 75
# Threads: 10
# Temps concurrent: 1.3441 segons
# Productes descarregats correctament: 75

# %% [markdown]
# <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span> **Exercici 5.3 (0.5 punts)**
#
# En la pràctica, existeixen diferents estratègies per millorar el rendiment d’un programa que realitza tasques repetitives o amb temps d’espera.
#
# 1. Considereu que continuar augmentant el nombre de threads milloraria encara més el rendiment? Justifiqueu breument la vostra resposta.
# 2. Valoreu si, per a aquest problema, una solució basada en `multiprocessing` resultaria més adequada que una solució basada en `multithreading`, justificant la vostra resposta.

# %% [markdown]
# >1. Continuar augmentant el nombre de threads no milloraria indefinidament el rendiment. Al principi, afegir més threads pot reduir el temps total perquè permet descarregar diversos productes alhora i aprofitar els temps d'espera de la xarxa. Ara bé, a partir d'un cert punt el guany s'estanca o fins i tot pot empitjorar, perquè apareixen costos addicionals de gestió dels threads, més competència pels recursos del sistema i possibles limitacions de la xarxa o del servidor de l'API. Per tant, el millor nombre de threads és el que minimitza el temps en les proves realitzades, no necessàriament el nombre més alt.
# >
# >2. Per a aquest problema, una solució basada en multithreading és més adequada que una basada en multiprocessing. La descàrrega de fitxers JSON és una tasca principalment d'entrada/sortida, ja que el programa passa bona part del temps esperant la resposta del servidor. En aquest tipus de tasques, els threads són eficients perquè permeten solapar aquests temps d'espera amb altres descàrregues. En canvi, multiprocessing seria més útil en tasques intensives en CPU, com càlculs matemàtics pesats o processament d'imatges, on diferents processos poden executar-se realment en paral·lel. En aquest cas, crear processos tindria més sobrecost que crear threads, i no aportaria un avantatge clar, perquè el coll d'ampolla principal no és el càlcul sinó l'espera de xarxa.
# >
# >**Fonts:**
# >*Unitat 5: Optimització de codi: programació concurrent i paral·lela*
# >- *1. Introducció — diferències entre threads i processos: cost de creació, compartició de memòria i overhead*
# >- *2.2. Optimització de codi fent servir threads en Python — quan els threads milloren el rendiment: tasques d'I/O vs. tasques de CPU*
# >- *3.2. Optimització de codi fent servir multiprocés en Python — quan el multiprocessament és avantatjós: tasques intensives en CPU sense dependències entre resultats*
