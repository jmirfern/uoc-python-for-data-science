# %% [markdown]
# <div style="width: 100%; clear: both;">
#     <div style="float: left; width: 50%;">
#        <img src="https://www.uoc.edu/portal/system/modules/edu.uoc.presentations/resources/img/branding/logo-uoc-default.png", align="left" width="125px">
#     </div>
# </div>
#
# <div style="float: right; width: 50%;">
#     <p style="margin: 0; padding-top: 22px; text-align:right;">22.403 · Programació per a la ciència de dades</p>
#     <p style="margin: 0; text-align:right;">Grau en Ciència de Dades Aplicada</p>
#     <p style="margin: 0; text-align:right; padding-button: 100px;">Estudis d'Informàtica, Multimèdia i Telecomunicació</p>
# </div>
# </div>

# %% [markdown]
# Programación para la ciencia de datos - PEC3
# ============================

# %% [markdown]
# En este Notebook encontraréis un conjunto de ejercicios que suponen la tercera actividad de evaluación continua (PEC) de la asignatura.
#
# Para cada ejercicio, tened en cuenta que:
#
# - **Es necesario incluir comentarios** en vuestro código, que expliquen cómo habéis implementado la solución del problema planteado.
# - **Es imprescindible** citar las referencias consultadas.
# - **Se valorará** que el código proporcionado solucione el problema propuesto y también la calidad del código (comentarios, legibilidad, claridad, uso de las estructuras de datos adecuadas, buena nomenclatura de las variables y funciones, seguimiento del PEP8, etc.). En esta PEC 3 es particularmente importante que el código desarrollado sea eficiente.
#
# Veréis que todas las actividades tienen una etiqueta, que indica los recursos necesarios para llevarla a cabo. Hay tres posibles etiquetas:
#
# * <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 3px; ">SM</span>**Sólo materiales**: las herramientas necesarias para realizar la actividad se pueden encontrar en los materiales de la asignatura (consideraremos también los materiales de la asignatura Fundamentos de Programación, así como las lecturas obligatorias de material externo que se indican en los notebooks).
# * <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span>**Consulta externa guiada**: la actividad puede requerir hacer uso de herramientas que no se encuentran en los materiales de la asignatura, pero el enunciado contiene indicaciones de dónde o cómo encontrar la información adicional necesaria para resolver la actividad.
# * <span style="font-family: Courier New; background-color: #f2ae72; color: #000000; padding: 3px; ">EI</span>**Consulta externa independiente**: la actividad puede requerir hacer uso de herramientas que no se encuentran en los materiales de la asignatura, y el enunciado puede no incluir la descripción de dónde o cómo encontrar esta información adicional. Será necesario que el estudiante busque esta información utilizando los recursos que se han explicado en la asignatura.
#
# Notad que estas etiquetas no indican el nivel de dificultad del ejercicio, sino únicamente la necesidad de consulta de documentación externa para su resolución. Además, recordad que las**etiquetas son informativas**, pero **podéis consultar referencias externas, y usarlas, siempre que queráis (aunque no se indique explícitamente). De la misma forma, podéis realizar una actividad sin consultar ningún tipo de documentación**. Por ejemplo, para resolver una actividad que sólo requiera los materiales de la asignatura, podéis consultar referencias externas, ya sea para ayudar a resolverla o para ampliar conocimientos.

# %% [markdown]
# **Importante**: Además de la puntuación de cada ejercicio, que valora la calidad de la solución que propone y los resultados obtenidos, en esta PEC se valoran 3 aspectos adicionales, transversales a todas las actividades:
#
# * **Documentación**(**0.25*f puntos**): Todas las funciones de los ejercicios de esta PEC deberán ser correctamente documentadas utilizando docstrings (en el formato que prefiera).
#
# * **Modularidad**(**0.5*f puntos**): Se valorará la modularidad del código (la correcta estructuración del código en funciones).
# * **Estilo**(**0.25*f puntos**): El código debe seguir la guía de estilo de Python [PEP8](https://www.python.org/dev/peps/pep-0008/), exceptuando los casos en los que hacerlo complique la legibilidad del código.
#
# Donde $f$ es la fracción de la PEC realizada. Es decir, la nota de estos aspectos transversales será proporcional a la parte de la PEC realizada.
#
# Así, los aspectos transversales tendrán una puntuación máxima de 1 punto si se entregan todos los ejercicios de la PEC. De lo contrario, la nota de aspectos transversales se multiplicará por la fracción de la PEC entregada. Por ejemplo, si los aspectos transversales están puntuados con un 1 y sólo existe la mitad de la PEC entregada, la nota de los aspectos transversales será $1*0.5=0.5$.
#
# La nota de los aspectos transversales se considera incluida en las mencionadas notas para los ejercicios.

# %% [markdown]
# ---
#
# ## Antes de empezar
#
# Por favor, leed atentamente los siguientes párrafos relativos a la originalidad en las actividades de la asignatura antes de empezar a trabajar en la PEC.
#
# <div class="alert alert-block alert-success">La falta de originalidad se produce cuando en una actividad aparece contenido que no ha sido elaborado de forma individual por el estudiante y no se referencia adecuadamente su origen. O bien cuando, aunque el contenido externo esté referenciado, éste es tan extenso que no es posible considerar al estudiante el autor o autora de la actividad.
# <br /><br />
# Así, algunos ejemplos de comportamientos inadecuados son en lo que se refiere a la falta de originalidad son:
# <ol>
#     <li>Crear la solución de un ejercicio de la PEC en colaboración entre varios estudiantes.</li>
#     <li>Incluir un ejercicio de la PEC que utilice código encontrado en internet sin citar la fuente.</li>
#     <li>Compartir su solución de la PEC con otros estudiantes de la asignatura.</li>
#     </ol>
# </div>
#
# ## Instrucciones de entrega
#
# Para proceder a la entrega de la actividad es necesario realizar los siguientes pasos:
#
# 1. Comprobad que el notebook se ejecuta correctamente. Es importante que antes de entregar vuestra PEC os aseguréis que la versión final del código ejecuta correctamente en su totalidad. Para ello, se recomienda hacer una ejecución completa desde cero del notebook haciendo click en *Kernel > Restart & Run All*, y comprobando que todas las celdas del notebook se ejecutan correctamente.
# 2. Confirmad que sois los autores únicos de la PEC y que esta incluye todas las citas a recursos externos que se hayan utilizado para elaborarla. Con el fin de confirmar que sois los autores únicos de la actividad, añadid vuestro nombre completo en la celda siguiente.
# 3. Generar un archivo comprimido que incluya todos los archivos de la PEC (tanto el archivo con el notebook, con extensión .ipynb, como las carpetas con los datos necesarios para ejecutarlo). Aseguraos de que se puede descomprimir este archivo en cualquier directorio del ordenador y que el código se ejecuta sin problemas.
# 5. Entregar la PEC a través del Registro de Evaluación Continuada del aula.

# %% [markdown]
# <div class="alert alert-block alert-warning">Yo, *Nombre y Apellidos*, confirmo que he elaborado de manera individual todas las actividades resueltas en esta PEC y que he incluido las citas en todas las fuentes externas que he utilizado para resolver las actividades. </div>

# %% [markdown]
# Como se ha comentado más arriba, en esta PEC se valora y puntúa seguir la guía de estilo de Python **PEP8**. Sin embargo, no es necesario activar las alertas de estilo con **pycodestyle**. Se entiende que el alumno a estas alturas ya tiene que seguir las reglas de estilo que ayudan a la legibilidad del código.

# %% [markdown]
# ## Ejercicio 1
#
# En este primer ejercicio trabajaremos con el orden de crecimiento de diferentes funciones, un concepto fundamental para analizar la eficiencia de los algoritmos.
#
# El análisis asintótico permite estudiar cómo evoluciona el tiempo de ejecución de un algoritmo en función del tamaño de la entrada, dejando de lado detalles concretos de implementación o del hardware utilizado.
#
# Comprender el crecimiento de las funciones permite evaluar la complejidad de los algoritmos y estimar su comportamiento a medida que aumenta el tamaño de la entrada, sirviendo como base para análisis posteriores orientados a su mejora u optimización.

# %% [markdown]
# <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 3px; ">SM</span> **Ejercicio 1.1 (0.5 puntos)**
#
# Cuando se analiza la complejidad de un algoritmo en función del crecimiento de su tiempo de ejecución, se utilizan distintos términos.
#
# Indicad brevemente, para cada una de las siguientes funciones, qué término se utiliza habitualmente en el análisis de algoritmos para describir su tipo de crecimiento.
#
# Considerad las siguientes funciones:
#
# - $n\log(n)$
# - $e^n$
# - $n!$
# - $\log(n)$
# - $n$
# - $2n^2 + 3n + 4$
# - $1^n$

# %% [markdown]
# <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 3px; ">SM</span> **Ejercicio 1.2 (0.5 puntos)**
#
# Ordenad las funciones del apartado anterior de menor a mayor según su orden de crecimiento.

# %% [markdown]
# <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 3px; ">SM</span> **Ejercicio 1.3 (0.5 puntos)**
#
# En este ejercicio tenéis que identificar qué pares de funciones presentan un orden de crecimiento similar entre los dos conjuntos siguientes.
#
#
# **Conjunto A**
#
# - $n^2$
# - $\log(n)$
# - $n\log(n)$
# - $2^n$
# - $n$
# - $n!$
#
# **Conjunto B**
#
# - $n\log(n^2)$
# - $3n$
# - $e^n$
# - $\log(n^2)$
# - $n^2 + n$
# - $(n+1)!$
#
#
# Justificad brevemente por qué ambas funciones presentan el mismo orden de crecimiento asintótico.

# %% [markdown]
# ## Ejercicio 2
#
# En este apartado analizaremos la eficiencia temporal de diferentes fragmentos de código.
#
# El objetivo es comprender cómo el tamaño de la entrada afecta al tiempo de ejecución de un algoritmo y aprender a identificar posibles ineficiencias en su implementación.
#
# Recordad que, al analizar la eficiencia de un algoritmo, normalmente se considera el **caso peor**, es decir, aquel en el que el algoritmo requiere el mayor número de operaciones para completarse.

# %% [markdown]
# <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span> **Ejercicio 2.1 (0.75 puntos)**
#
#
# Indicad la complejidad algorítmica $\Theta$ en relación al tiempo de ejecución del siguiente fragmento de código, justificando vuestra respuesta.

# %%
def extract_active_bits(x: int) -> int:
    """
    Compute the number of active bits in the binary 
    representation of an int.

    Args:
        x (int): Input integer.

    Returns:
        int: Number of active bits.
    """
    count: int = 0
    value: int = x

    while value > 1:
        bit: int = value % 2
        value = value // 2

        if bit == 1:
            count += 1

    if value == 1:
        count += 1

    return count

# %% [markdown]
# <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span> **Ejercicio 2.2 (0.75 puntos)**
#
# En este ejercicio también analizaréis un fragmento de código con el objetivo de detectar posibles ineficiencias y comprender su complejidad temporal.
#
# Justificad brevemente el análisis del algoritmo, indicad su complejidad temporal y comentad dónde se encuentra la principal ineficiencia del código.
#
# **Nota:**
# - En este ejercicio podéis asumir que la dimensión de los embeddings es fija (por ejemplo, **1408**).

# %%
def find_most_similar(query: list[float], embeddings: list[list[float]]) -> int:
    """
    Find the index of the most similar embedding using squared 
    Euclidean distance.

    Args:
        query (list[float]): Query embedding.
        embeddings (list[list[float]]): Database of embeddings.

    Returns:
        int: Index of the most similar embedding.
    """
    best_index = -1
    best_distance = float("inf")

    for i in range(len(embeddings)):
        distance = 0.0

        for j in range(len(query)):
            diff = query[j] - embeddings[i][j]
            distance += diff * diff

        if distance < best_distance:
            best_distance = distance
            best_index = i

    return best_index

# %% [markdown]
# ## Ejercicio 3
#
# En este ejercicio detectaréis las ineficiencias y mejoraréis el código.

# %% [markdown]
# <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 3px; ">SM</span> **Ejercicio 3.1 (1 punto)**
#
# Utilizando las herramientas de *profiling* que hemos visto en el Notebook de teoría, analizad el siguiente fragmento de código ineficiente e identificad cuál es el cuello de botella del algoritmo.
#
# Para ello, tenéis que realizar lo siguiente:
#
# - Generad una lista de enteros (10.000 elementos) para poder analizar el rendimiento del algoritmo.
#
# - Analizad el rendimiento de la función utilizando `%timeit`  y `%lprun`.
#
# - A partir de los resultados obtenidos con ambas herramientas, identificad qué parte del algoritmo constituye el cuello de botella y explicad las ineficiencias detectadas, relacionándolas con los resultados obtenidos mediante el *profiling*.
#
# - Indicad cuál es la complejidad temporal aproximada del algoritmo y justificad vuestra respuesta.

# %%
from typing import List, Dict

def compute_frecs(values: List[int]) -> Dict[int, int]:
    """
    Computes the frequency of each value in the input list.

    Args:
        values: List of integer values.

    Returns:
        Dictionary mapping each value to its frequency.
    """
    frecs: Dict[int, int] = {}
    for j in range(len(values)):
        current_value = values[j]
        count = 0
        for k in range(len(values)):
            if values[k] == current_value:
                count += 1
        frecs[current_value] = count
    return frecs

# %% [markdown]
# <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span> **Ejercicio 3.2 (0.5 puntos)**
#
# En este ejercicio debéis mejorar el algoritmo `compute_frecs` con el objetivo de reducir su tiempo de ejecución y mejorar su eficiencia.
#
# Para ello, cread una nueva función llamada `compute_frecs_improved` e implementad el código correspondiente.
#
# Además, debéis:
# - Medid el tiempo de ejecución de `compute_frecs_improved` utilizando `%timeit`, comparadlo con el obtenido anteriormente para `compute_frecs` y calculad el *speed-up* de la versión optimizada respecto a la original.
# - Explicad qué mejora habéis introducido respecto a la versión original del algoritmo.
# - Indicad cuál es la complejidad temporal aproximada de la nueva versión.

# %% [markdown]
# <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span> **Ejercicio 3.3 (0.5 puntos)**
#
# Cuando optimizamos un algoritmo estamos modificando su implementación, pero es fundamental asegurarse de que el comportamiento funcional no cambia. Además, también es importante visualizar la mejora en el rendimiento, ya que muchas veces las optimizaciones se entienden mejor al observar cómo cambia el tiempo de ejecución.
#
# En este apartado debéis realizar lo siguiente:
#
# - **Verificación de resultados:** comprobad que ambas implementaciones (`compute_frecs` y `compute_frecs_improved`) producen el mismo resultado utilizando varias listas de entrada. Para ello, añadid comprobaciones con `assert` que comparen las salidas de ambas funciones.
#     - Utilizad:
#     ```python
#     values1 = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]
#     values2 = [10, 5, 10, 3, 5, 3, 3, 8, 8, 8, 1, 1, 1]
#     ```
#
# - **Comparación del rendimiento:** generad listas de diferentes tamaños y medid el tiempo de ejecución de ambos algoritmos. Representad los resultados en una gráfica que muestre cómo crece el tiempo de ejecución en función del tamaño de la lista \(n\).
#     - Utilizad los siguientes tamaños:
#     ```python
#     sizes = [200, 300, 500, 750, 1200, 3000]
#     ```

# %% [markdown]
# ## Ejercicio 4
#
# En este ejercicio trabajaremos con el módulo `multiprocessing` para comparar la ejecución secuencial frente a la paralela de una misma tarea computacional.

# %% [markdown]
# <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span> **Ejercicio 4.1 (1 punto)**
#
# Se proporciona una función que, dada una imagen en escala de grises representada mediante una matriz, cuenta cuántos píxeles tienen un valor superior a un determinado umbral. A partir de esta función ya implementada, se pide desarrollar dos nuevas funciones:
#
# - **Versión secuencial:** Implementad una función que reciba una lista de imágenes y aplique secuencialmente la función `count_white_pixels()`, midiendo y mostrando el tiempo total de ejecución en segundos.
#
# - **Versión con multiprocesamiento:** Implementad otra función que realice el mismo cálculo, pero utilizando múltiples procesos mediante el módulo `multiprocessing`, también mostrando el tiempo total de ejecución.
#
# Ambas funciones deberán utilizar la misma lista de entrada y permitir comparar el rendimiento entre la ejecución secuencial y la paralela. Para ello, se proporciona también el listado de matrices, que simulan imágenes de distintos tamaños y que deberá utilizarse como entrada común en ambas implementaciones.
#
# **IMPORTANTE**: Dependiendo del sistema y del entorno de ejecución, el multiprocesamiento puede no funcionar correctamente directamente en un notebook. Si esto ocurre, deberás mover las funciones a un módulo de Python independiente (.py).

# %%
import numpy as np
import multiprocessing as mp

def count_white_pixels(image: np.ndarray, threshold: int = 200) -> int:
    """
    Counts how many pixels in a grayscale image are greater than a 
    given threshold.

    Args:
        image (np.ndarray): Image represented as a 2D NumPy array.
        threshold (int): Threshold value used to determine whether 
        a pixel is considered white.

    Returns:
        int: Number of pixels greater than the threshold.
    """
    count = 0
    rows, cols = image.shape

    for i in range(rows):
        for j in range(cols):
            if image[i, j] > threshold:
                count += 1

    return count


images = [
    np.random.randint(0, 256, (2000, 2000), dtype=np.uint8),
    np.random.randint(0, 256, (2500, 2500), dtype=np.uint8),
    np.random.randint(0, 256, (3000, 3000), dtype=np.uint8),
    np.random.randint(0, 256, (3500, 3500), dtype=np.uint8),
]

# %% [markdown]
# <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span> **Ejercicio 4.2 (1 punto)**
#
# En este apartado se analizará el comportamiento del programa al ejecutarse de forma secuencial y al ejecutarse mediante procesamiento en paralelo.
#
# - A partir de los resultados obtenidos, ¿es mejor la versión paralela que la secuencial?
#
# - Identifica y explica los costes adicionales asociados al uso de multiprocesamiento.
#
# - ¿En qué situaciones una ejecución paralela puede resultar más lenta que una secuencial?

# %% [markdown]
# # Ejercicio 5
#
# Una empresa dedicada al comercio electrónico os ha solicitado desarrollar un sistema de recopilación de información de productos desde una API pública. Cada recurso se obtiene en formato JSON e incluye información descriptiva del producto, así como valores numéricos como el precio, el descuento, la valoración o el stock.
#
# El objetivo es descargar estos recursos, almacenarlos localmente y evaluar el rendimiento del proceso utilizando distintas estrategias de ejecución.
#
# Para facilitar el acceso a los datos, se os proporcionan las siguientes funciones base. La primera genera una lista de URLs correspondientes a 75 productos de la API pública, y la segunda muestra cómo descargar un único recurso JSON y almacenarlo localmente.

# %%
def get_json_urls(num: int = 75) -> list[str]:
    """
    Generates a list of product JSON URLs from the API.

    Args:
        num: Number of product URLs to generate.

    Returns:
        A list of product JSON URLs.
    """
    return [f"https://dummyjson.com/products/{i}" for i in range(1, num + 1)]

# %%
import json
import requests

def download_json(url: str, output_path: str) -> None:
    """
    Downloads a JSON resource from a URL and saves it locally.

    Args:
        url: URL of the JSON resource.
        output_path: Local path where the JSON file will be stored.
    """
    response: requests.Response = requests.get(url, timeout=10)
    response.raise_for_status()

    data: dict = response.json()

    # Save JSON content into a local file
    with open(output_path, "w", encoding="utf-8") as file:
        json.dump(data, file, indent=4, ensure_ascii=False)

# %% [markdown]
# <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span> **Ejercicio 5.1 (0.5 puntos)**
#
# Implementad una versión secuencial del sistema de descarga de productos en formato JSON.
#
# Para ello, debéis obtener una lista de URLs de productos desde una API pública y recorrerla una a una, descargando cada recurso y almacenándolo localmente en una carpeta, por ejemplo, `products/`.
#
# Cada fichero deberá guardarse con un nombre único, como product_1.json, product_2.json, etc.
#
# Durante el proceso, debéis:
#
# - Medir y mostrar el tiempo total de ejecución de la descarga secuencial,
# - Indicar cuántos productos se han descargado correctamente.

# %% [markdown]
# <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span> **Ejercicio 5.2 (1 punto)**
#
# Implementad una versión concurrente del sistema de descarga de productos.
#
# Para ello, debéis reutilizar la lógica de descarga del ejercicio anterior y adaptarla para que múltiples productos puedan descargarse de forma concurrente mediante la clase `ThreadPoolExecutor`.
#
# Cada fichero deberá seguir almacenándose localmente en la carpeta `products/`, utilizando un nombre único para cada producto.
#
# Por lo tanto:
#
# - Comparad brevemente el resultado obtenido con el tiempo de la versión secuencial.
# - Probad distintos valores para el número de threads con el fin de determinar cuál ofrece el mejor rendimiento.
# - Representad en una gráfica los tiempos obtenidos para los distintos valores de threads.
# - Indicad qué número de threads proporciona el mejor resultado.
#
# **Nota:**
#
# Podéis probar, por ejemplo, valores entre 1 y 10 para `max_workers`.

# %% [markdown]
# <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span> **Ejercicio 5.3
#  (0.5 puntos)**
#
# En la práctica, existen distintas estrategias para mejorar el rendimiento de un programa que realiza tareas repetitivas o con tiempos de espera.
#
# 1. ¿Consideráis que seguir aumentando el número de threads mejoraría aún más el rendimiento? Justificad brevemente vuestra respuesta.
# 2. Valorad si, para este problema, una solución basada en multiprocessing resultaría más adecuada que una solución basada en multithreading, justificando vuestra respuesta.
