# %% [markdown]
# <div style="width: 100%; clear: both;">
#     <div style="float: left; width: 50%;">
#        <img src="http://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/UOC_Masterbrand.jpg", align="left">
#     </div>
# </div>
#
# <div style="float: right; width: 50%;">
#     <p style="margin: 0; texto-align:right;">22.503 · Programación para la ciencia de datos</p>
#     <p style="margin: 0; texto-align:right;">Grado en Ciencia de Datos Aplicada</p>
#     <p style="margin: 0; texto-align:right; padding-button: 100px;">Estudios de Informática, Multimedia y Telecomunicaciones</p>
# </div>
#
# </div>
# <div style="width: 100%; clear: both;">
# <div style="width:100%;"> </div>

# %% [markdown]
# # Programación para la ciencia de datos - PAC2
#
# En este Notebook encontrarás un conjunto de ejercicios que conforman la segunda actividad de evaluación continua (PEC) de la asignatura.
#
# Para cada ejercicio, ten en cuenta que:
#
# * **Es necesario incluir comentarios** en tu código, que expliquen cómo has implementado la solución del problema planteado.
# * **Es imprescindible** citar las referencias consultadas para realizar la actividad. Se valorará que el código proporcionado solucione el problema propuesto y también la calidad del código (comentarios, legibilidad, claridad, uso de las estructuras de datos adecuadas, buena nomenclatura de las variables y funciones, cumplimiento del PEP8, etc.).
#
# Verás que cada una de las actividades tiene asociada una puntuación, que indica el peso que tiene la actividad sobre la nota de la PAC.
# Adicionalmente, hay una puntuación asociada a aspectos globales de la PAC (*docstring*, modularidad y estilo), que se evaluarán sobre la totalidad del código entregado.
#
# Además, todas las actividades tienen una etiqueta, que indica los recursos necesarios para realizarla.
# Hay tres posibles etiquetas:
#
# * <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 3px;">SM</span> **Solo materiales**: las herramientas necesarias para realizar la actividad se pueden encontrar en los materiales de la asignatura (consideraremos también los materiales de la asignatura Fundamentos de Programación, así como las lecturas obligatorias de material externo que se indican en los notebooks).
#
# * <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px;">EG</span> **Consulta externa guiada**: la actividad puede requerir el uso de herramientas que no se encuentran en los materiales de la asignatura, pero el enunciado contiene indicaciones de dónde o cómo encontrar la información adicional necesaria para resolver la actividad.
#
# * <span style="font-family: Courier New; background-color: #f2ae72; color: #000000; padding: 3px;">EI</span> **Consulta externa independiente**: la actividad puede requerir el uso de herramientas que no se encuentran en los materiales de la asignatura, y el enunciado puede no incluir la descripción de dónde o cómo encontrar esta información adicional. Será necesario que el estudiante busque esta información utilizando los recursos que se han explicado en la asignatura.
#
# Es importante notar que estas etiquetas no indican el nivel de dificultad del ejercicio, sino únicamente la necesidad de consultar documentación externa para su resolución.
# Además, recuerda que las **etiquetas son informativas**, pero puedes consultar referencias externas siempre que lo desees (aunque no se indique explícitamente) o puede que seas capaz de realizar una actividad sin consultar ningún tipo de documentación.
# Por ejemplo, para resolver una actividad que solo requiera los materiales de la asignatura, puedes consultar referencias externas si lo deseas, tanto para ayudar en la resolución como para ampliar conocimientos.

# %% [markdown]
# ## Criterios de corrección
#
# Esta PEC se evaluará siguiendo los siguientes criterios:
#
# * **Funcionalidad** (9 puntos): Se valorará que el código implemente las funcionalidades correspondientes.
#      * Ejercicio 1 (1 punto)
#      * Ejercicio 2 (2 puntos)
#      * Ejercicio 3 (2 puntos)
#      * Ejercicio 4 (2 puntos)
#      * Ejercicio 5 (2 puntos)
#
# * **Documentación** (0.25f puntos): Todas las funciones de los ejercicios de esta PEC deberán estar debidamente documentadas utilizando docstrings (en el formato que prefieras).
# * **Modularidad** (0.5f puntos): Se valorará la modularidad del código (tanto la organización del código en módulos como la creación de funciones).
# * **Estilo** (0.25f puntos): El código debe seguir la guía de estilo de Python (PEP8), exceptuando los casos en los que hacerlo complique la legibilidad del código.
#
# Donde *f* es la fracción de la PEC realizada. Es decir, la nota de estos aspectos transversales será proporcional a la parte de la PEC realizada.
# Así, los aspectos transversales tendrán una puntuación máxima de 1 punto si se entregan todos los ejercicios de la PEC.
# En caso contrario, la nota de los aspectos transversales se multiplicará por la fracción entregada de la PEC.
# Por ejemplo, si los aspectos transversales están puntuados con un 1 y solo se ha realizado media PEC, la nota de los aspectos transversales será 1∗0.5=0.5.

# %% [markdown]
# # Ejercicio 1: Manejo de ficheros
#
# <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 3px;">SM</span> **(1 punto)**
#
# Escribe un código en python que realice las siguientes tareas utilizando la librería os:
#
# * 1: (0,25) Cree una carpeta que se llame 'resultados_PEC2'.
# * 2: (0,25) Dentro de esa carpeta, crea un archivo de texto llamado resumen.txt.
# * 3: (0,25) Crea un fichero con el siguiente contenido:
#
#     "Línea 1: Creación de la carpeta resultados.\n"
#
#     "Línea 2: Creación del fichero resumen.\n"
#
#     "Línea 3: Información incluida en el fichero.\n"
#
# * 4: (0,25) Muestra por pantalla el nombre del archivo y su extensión por separado.

# %%
import os

# 1: Crear carpeta
folder_name = "procesamiento_datos"
if not os.path.exists(folder_name):
    os.mkdir(folder_name)

# 2: Crear el archivo.
file_path = os.path.join(folder_name, "resumen.txt")
# 3. escribir contenido usando el bucle 'with'.
with open(file_path, "w") as f:
    f.write("Línea 1: Inicio del procesamiento.\n")
    f.write("Línea 2: Datos cargados correctamente.\n")
    f.write("Línea 3: Fin del reporte.\n")

# 4. Obtener nombre y extensión
base_name = os.path.basename(file_path)
name_only, extension = os.path.splitext(base_name)

print(f"Archivo: {name_only}")
print(f"Extensión: {extension}")
# Out:
# Archivo: resumen
# Extensión: .txt

# %% [markdown]
# # Ejercicio 2: Uso de funciones y pandas
#
# <span style="font-family: Courier New; background-color: #82b74b; color: #000000; padding: 3px;">SM</span> **(2 puntos)**
#
# Una consultora tecnológica nos ha pedido procesar un histórico de datos sobre la evolución de la Inteligencia Artificial almacenado en el archivo usoDeInteligenciaArtificial.csv.
#
# 1.1: (0,5 puntos) Crea una función llamada Filtrar_Ingresos_Altos que reciba un umbral de ingresos y devuelva las filas del dataframe que superen dicho umbral, ordenadas de forma descendente.
#
# 1.2: (0,5 puntos) Crea una función llamada Calcular_Volumen_Empleo que añada al dataframe una nueva columna Total_Jobs_Volume (suma de empleos creados y eliminados) y devuelva el dataframe modificado.
#
# 1.3: (0,5 puntos) Crea una función llamada Metricas_Riesgo_Sector que reciba el nombre de una columna de riesgo y devuelva un diccionario con el valor máximo, el mínimo y la media.
#
# 1.4: (0,5 puntos) Crea una función llamada Analisis_Adopcion_Periodo que reciba dos años y devuelva un mensaje formateado con el incremento de adopción de IA.

# %%
import pandas as pd

# 2.0. Carga de datos
df = pd.read_csv("data/usoDeInteligenciaArtificial.csv")

# 2.1: Función para filtrar ingresos
def Filtrar_Ingresos_Altos(umbral: float):
    """
    Filtra el DF por ingresos de software > umbral y ordena descendente.
    """
    filtro = df[df["AI Software Revenue(in Billions)"] > umbral]
    resultado = filtro.sort_values(by="AI Software Revenue(in Billions)", ascending=False)
    return resultado

print("\n 2.1: Años con ingresos > 50 Billions (ordenado)")
print(Filtrar_Ingresos_Altos(50)[["Year", "AI Software Revenue(in Billions)"]])

# 2.2: Función para volumen de empleo
def Calcular_Volumen_Empleo(data: pd.DataFrame):
    """
    Crea la columna Total_Jobs_Volume y retorna el DF.
    """
    # Creamos una copia para no modificar el original fuera de la función si no se desea
    df_mod = data.copy()
    df_mod["Total_Jobs_Volume"] = (
        df_mod["Estimated Jobs Eliminated by AI (millions)"] + 
        df_mod["Estimated New Jobs Created by AI (millions)"]
    )
    return df_mod

print("\n2.2: Primeras filas con la nueva columna de volumen de empleo")
df = Calcular_Volumen_Empleo(df) # Actualizamos nuestro df global
print(df[["Year", "Total_Jobs_Volume"]].head())

# 2.3: Función de métricas de riesgo por sector
def Metricas_Riesgo_Sector(columna_sector: str):
    """
    Calcula max, min y media de una columna de riesgo (limpiando el %).
    """
    # Convertir a numérico eliminando el símbolo % si está presente
    serie_numerica = df[columna_sector].replace('%', '', regex=True).astype(float)
    
    return {
        "Sector": columna_sector,
        "Maximo": serie_numerica.max(),
        "Minimo": serie_numerica.min(),
        "Media": round(serie_numerica.mean(), 2)
    }

print("\n 2.3: Análisis de riesgo en 'Manufacturing'")
print(Metricas_Riesgo_Sector("Jobs at High Risk of Automation - Manufacturing"))

# 2.4: Función de incremento de adopción en un periodo
def Analisis_Adopcion_Periodo(año_inicio: int, año_fin: int) -> str:
    """
    Calcula la variación de adopción entre dos años.
    """
    # Limpieza local para el cálculo
    adopcion_num = df["AI Adoption (%)"].str.replace('%', '').astype(float)
    
    # Obtener valores buscando por el índice del año
    val_inicio = adopcion_num[df["Year"] == año_inicio].values[0]
    val_fin = adopcion_num[df["Year"] == año_fin].values[0]
    
    incremento = val_fin - val_inicio
    
    return (f"Para el periodo {año_inicio}-{año_fin}, la adopción aumentó en "
            f"{incremento:.1f} puntos porcentuales.")

print("\n 2.4: Resultado del periodo 2018-2023")
print(Analisis_Adopcion_Periodo(2018, 2023))
# Out:
#  2.1: Años con ingresos > 50 Billions (ordenado)
#    Year  AI Software Revenue(in Billions)
# 7  2025                            126.00
# 6  2024                             94.41
# 5  2023                             70.94
# 4  2022                             51.27
#
# 2.2: Primeras filas con la nueva columna de volumen de empleo
#    Year Total_Jobs_Volume
# 0  2018             10%5%
# 1  2019             15%8%
# 2  2020            20%12%
# 3  2021            25%16%
# 4  2022            30%20%
#
#  2.3: Análisis de riesgo en 'Manufacturing'
# {'Sector': 'Jobs at High Risk of Automation - Manufacturing', 'Maximo': np.float64(50.0), 'Minimo': np.float64(46.4), 'Media': np.float64(48.24)}
#
#  2.4: Resultado del periodo 2018-2023
# Para el periodo 2018-2023, la adopción aumentó en 25.0 puntos porcentuales.

# %% [markdown]
# # Ejercicio 3 Uso de funciones y archivos.
#
# <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px;">EG</span> **(2 puntos)**
#
# 3.1: (1 punto) Crea una función que se llame `job_impact_by_year` que reciba como datos de entrada:
#
# - La ruta del archivo
# - Un año específico.
#
# La función devolverá un diccionario donde la clave sea el año y el valor sea una lista de tuplas con el impacto laboral: {año : [('categoría', 'xx%'), ('categoría', 'xx%')]}
#
# 3.2: (1 punto) Crea otra función llamada `automation_risk_dict` que reciba como datos de entrada:
#
# - La ruta del archivo
# - Un umbral de riesgo (numérico).
#
# La función devolverá un diccionario donde la clave es el año y el valor es una lista de tuplas con los sectores que superan ese porcentaje de riesgo y su valor (Sector, Porcentaje): {año : [('sector', 'xx%'), ('sector', 'xx%')]}

# %%
#3.1

def job_impact_by_year(file_path: str, year: int) -> dict:
    df = pd.read_csv(file_path)
    # Convertimos a lista de tuplas (Year, Eliminated, Created)
    data = df[["Year", "Estimated Jobs Eliminated by AI (millions)", "Estimated New Jobs Created by AI (millions)"]].values.tolist()
    
    # Filtrado funcional por año
    filtered = list(filter(lambda x: x[0] == year, data))
    
    # Construcción del diccionario
    result = {}
    for y, elim, creat in filtered:
        result[y] = [("Eliminated", elim), ("Created", creat)]
    
    return result

# %%
#test para comprobar el ejercicio 3.1
job_impact_by_year("data/usoDeInteligenciaArtificial.csv", 2020)
# Out:
# {2020: [('Eliminated', '20%'), ('Created', '12%')]}

# %%
#3.2

def automation_risk_dict(file_path: str, threshold: float) -> dict:
    df = pd.read_csv(file_path)
    # Limpiamos los nombres de columnas para facilitar el manejo
    cols = ["Year", "Jobs at High Risk of Automation - Transportation & Storage (%)", 
            "Jobs at High Risk of Automation - Wholesale & Retail Trade", 
            "Jobs at High Risk of Automation - Manufacturing"]
    
    data = df[cols].values.tolist()
    sectors = ["Transportation", "Retail", "Manufacturing"]
    
    resultado = {}
    for row in data:
        year = int(row[0])
        # Usamos list comprehension y filter para los sectores que superan el umbral
        high_risk = [(sectors[i-1], row[i]) for i in range(1, 4) if float(str(row[i]).replace('%','')) > threshold]
        
        if high_risk:
            resultado[year] = sorted(high_risk, key=lambda x: x[1], reverse=True)
            
    return resultado

# %%
#test para comprobar el ejercicio 3.2
job_impact_by_year("data/usoDeInteligenciaArtificial.csv", 40.0)
# Out:
# {}

# %% [markdown]
# # Ejercicio 4: Uso de funciones y expresiones regulares
#
# <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px;">EG</span> **(2 puntos)**
#
# 4.1 (1 punto) Crea una función llamada `filter_automation_columns` que devuelva un diccionario. La clave debe ser el nombre de la columna que contenga la palabra "Risk" seguida de un guion o espacio, y el valor debe ser el dato correspondiente al año 2021.
# Nota importante. Las expresiones regulares deben buscar palabras que contengan la palabra "risk" independientemente de que sean mayúsculas o minúsculas y debe de venir seguda de un caracter de puntuación o un espacio en blanco.
#
# 4.2 (1 punto) Crea una función llamada `get_adoption_metrics` que identifique todas las columnas que hablen de "Adoption" o "Implement". La función debe devolver un diccionario donde la clave sea el nombre de la columna y el valor sea el dato del último año registrado en el archivo. Nota importante: Las expresiones regulares deben buscar palabras que contengan palabras con las raíces "Adopt" o "Implement", siendo válidas cualquiera de las dos.

# %%
#4.1
import re

def filter_automation_columns(file_path: str) -> dict:
    df = pd.read_csv(file_path)
    
    # Filtramos la fila del año 2021
    df_2021 = df[df['Year'] == 2021]
    
    # Patrón: Contiene "risk", seguido de espacio o guion
    pattern = re.compile(r"risk[\s\-]", re.IGNORECASE)
    
    # Buscamos qué columnas cumplen el patrón
    target_columns = [col for col in df.columns if pattern.search(col)]
    
    # Creamos el diccionario con los valores de esas columnas para el 2021
    # .iloc[0] porque sabemos que solo hay una fila para ese año
    result = {col: df_2021[col].iloc[0] for col in target_columns}
    
    return result

# %%
#test para comprobar el ejercicio 4.1
filter_automation_columns("data/usoDeInteligenciaArtificial.csv")
# Out:
# {'Jobs at High Risk of Automation - Transportation & Storage (%)': '43%',
#  'Jobs at High Risk of Automation - Wholesale & Retail Trade': '47%',
#  'Jobs at High Risk of Automation - Manufacturing': '48%'}

# %%
#4.2

def get_adoption_metrics(file_path: str) -> dict:
    df = pd.read_csv(file_path)
    
    # Patrón para encontrar "Adopt..." o "Implement..."
    # Usamos | para "o"
    pattern = re.compile(r"Adopt|Implement", re.IGNORECASE)
    
    # Seleccionamos columnas
    matched_cols = [c for c in df.columns if pattern.search(c)]
    
    # Obtenemos la última fila (el año más reciente)
    last_row = df.iloc[-1]
    
    # Diccionario resultante
    return {col: last_row[col] for col in matched_cols}

# %%
#test para el ejercicio 4.2
get_adoption_metrics("data/usoDeInteligenciaArtificial.csv")
# Out:
# {'AI Adoption (%)': '63%',
#  'Organizations Planning to Implement AI': '58%',
#  'Global Expectation for AI Adoption (%)': '82%'}

# %% [markdown]
# # Ejercicio 5: Uso de funciones y lectura de ficheros
#
# <span style="font-family: Courier New; background-color: #ffcc5c; color: #000000; padding: 3px; ">EG</span> **(2.0 puntos)**
#
# Para este ejercicio, se desea saber qué palabras son las que se repiten más de una vez en un texto,
# por lo que se deberá crear una función que lea un texto y que calcule cuántas veces se repiten.
# Finalmente, se mostrarán las palabras que se repitan más de una vez. El archivo a utilizar es: Elladron.docx.
#
# Se pide crear la función `lectura` que recibirá la ruta donde se encuentra el archivo y deberá realizar lo siguiente:
#
# 1. Lectura del archivo
# 2. Conteo de todas las palabras del archivo
# 3. Filtrar las palabras que se repitan más de una vez.
#
# El resultado de esta función serán las palabras (que se repiten más de una vez) con las veces que se repite.
#
# **Notas importantes:**
#
# 1) Las palabras se cuentan por sí solas, es decir, si una palabra forma parte de otra no cuenta.
#
# 2) Si una palabra tiene alguna letra mayúscula y otra no, pero es la misma palabra, se cuentan como iguales, por lo tanto, suma al contador de la palabra.
#
# Ejemplo:
#
# <pre>
# Frase: La comida de la selva es mejor que la lasaña.
#
# Conteo de palabras:
#
# la: 3
# comida: 1
# de: 1
# selva: 1
# es: 1
# mejor: 1
# que: 1
# lasaña: 1
#
# Resultado de la función:
#
# la: 3
# </pre>
#
# **Nota:**
# Al tratarse de un archivo .docx ha de utilizar la librería adecuada para su lectura.

# %%
from docx import Document
from collections import Counter
import re

def lectura(MyDrive):
    # Leer el archivo Word
    doc = Document('data/Elladron.docx')

    # Extraer todo el texto del documento
    texto_completo = ""
    for parrafo in doc.paragraphs:
        texto_completo += parrafo.text + " "

    # Convertir todo el texto a minúsculas y dividir en palabras
    texto_completo = texto_completo.lower()

    # Usar una expresión regular para solo extraer palabras (ignorar números y puntuación)
    palabras = re.findall(r'\b\w+\b', texto_completo)

    # Contar la frecuencia de las palabras
    conteo_palabras = Counter(palabras)

    # Filtrar las palabras que se repiten más de una vez
    palabras_repetidas = {palabra: frecuencia for palabra, frecuencia in conteo_palabras.items() if frecuencia > 1}

    return palabras_repetidas

# Ejemplo de uso
ruta_docx = 'data/Elladron.docx'  # Ruta del archivo Word
palabras_repetidas = lectura(ruta_docx)

# Mostrar las palabras que se repiten más de una vez
print("Palabras que se repiten más de una vez:")
for palabra, frecuencia in palabras_repetidas.items():
    print(f"{palabra}: {frecuencia}")
# Out:
# Palabras que se repiten más de una vez:
# con: 13
# su: 27
# primer: 2
# robo: 2
# en: 30
# una: 13
# que: 62
# había: 19
# de: 73
# camino: 2
# al: 22
# fue: 3
# un: 18
# acto: 3
# sin: 9
# el: 28
# bolsa: 2
# aunque: 3
# nada: 4
# más: 7
# salir: 3
# a: 22
# la: 56
# se: 15
# después: 7
# mientras: 5
# no: 17
# le: 16
# pareció: 2
# hecho: 2
# tan: 3
# y: 36
# esa: 3
# mañana: 2
# entrar: 3
# casa: 6
# para: 8
# ser: 4
# recordó: 2
# ese: 2
# como: 7
# si: 5
# estaba: 13
# por: 12
# delante: 3
# hasta: 3
# quedar: 2
# estado: 3
# poder: 3
# apartar: 2
# lo: 14
# acababa: 2
# sensación: 4
# siempre: 2
# lugar: 3
# todo: 7
# él: 5
# empezó: 2
# desayuno: 2
# aquella: 2
# cuerpo: 5
# sobre: 8
# sus: 13
# sangre: 6
# junto: 3
# fuerte: 4
# tuvo: 2
# hizo: 4
# elegante: 2
# aquel: 2
# cadáver: 6
# boca: 2
# parte: 3
# del: 13
# cortina: 2
# dejaba: 2
# dudas: 2
# entonces: 3
# apareció: 3
# pensó: 5
# podía: 5
# irse: 2
# dejar: 2
# las: 8
# cosas: 2
# encima: 3
# además: 2
# ...
